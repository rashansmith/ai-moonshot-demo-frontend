# %%
import requests
import json

# %%
url = 'http://127.0.0.1:5000/'  
data1 = {
    'table_name': 'Projects',
    'prompt': ' top three highest budget only the  budget '
}
data2 = {
    'table_name': 'Projects',
    'prompt': ' the highest budget '
}
data3 = {
    'table_name': 'Projects',
    'prompt': ' top three projects with the highest budget, also include the budget '
}
data4 = {
    'table_name': 'Projects',
    'prompt': '  plot the top five project with the highest budget  '
}
error = {
    'table_name': 'Project',
    'prompt': 'plot the top three project with the highest budget'
}


response = requests.post(url, json=data4)

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'{"image": "..."}'

# %%
from json_image import image_to_json, json_to_image
json_to_image(response.content)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
